# %%
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('abc.jpg',0)

# %%
img.shape
# Out:
# (565, 959)

# %%
plt.imshow(img, cmap="gray")
plt.show()

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
face_cascade
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-a7021624f3f3> in <module>
# ----> 1 face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
#       2 face_cascade
#
# AttributeError: module 'cv2' has no attribute 'data'

# %%
faces_detect = face_cascade.detectMultiScale(img,1.1,4)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-29-2f08194400f4> in <module>
# ----> 1 faces_detect = face_cascade.detectMultiScale(img,1.1,4)
#
# error: OpenCV(3.4.2) C:\Miniconda3\conda-bld\opencv-suite_1534379934306\work\modules\objdetect\src\cascadedetect.cpp:1698: error: (-215:Assertion failed) !empty() in function 'cv::CascadeClassifier::detectMultiScale'
